# %% [markdown]
# # Loading data from the `peatfire` package
#
# After running `pip install -e .` once from the project root, you can import
# the package from any notebook — no `sys.path` hacks or `../` paths needed.

# %%
from peatfire import data_path, load_csv, DATA_DIR, PROJECT_ROOT

print("project root:", PROJECT_ROOT)
print("data dir:    ", DATA_DIR)

# %%
# Build a path to a data file (works regardless of where the notebook runs)
data_path("raw", "fires.csv")

# %%
# Load a CSV straight into a DataFrame
# df = load_csv("raw", "fires.csv")
# df.head()
